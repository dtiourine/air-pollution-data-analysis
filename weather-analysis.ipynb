# %% [markdown]
# #

# %%
import requests
import os
from dotenv import load_dotenv
import json

load_dotenv()
api_key = os.getenv("WEATHER_API_KEY")

# %%
def fetch_city_coordinates(api_key, city):
    url = f"http://api.openweathermap.org/geo/1.0/direct?q={city}&limit=5&appid={api_key}"
    response = requests.get(url)
    return response.json()

city_coordinates = fetch_city_coordinates(api_key, city="New York")
print(json.dumps(city_coordinates, indent=4))
# Out:
# [
#     {
#         "name": "New York County",
#         "local_names": {
#             "pl": "Nowy Jork",
#             "ar": "\u0646\u064a\u0648\u064a\u0648\u0631\u0643",
#             "hi": "\u0928\u094d\u092f\u0942\u092f\u094a\u0930\u094d\u0915\u094d",
#             "kn": "\u0ca8\u0ccd\u0caf\u0cc2\u0caf\u0cca\u0cb0\u0ccd\u0c95\u0ccd",
#             "es": "Nueva York",
#             "en": "New York",
#             "el": "\u039d\u03ad\u03b1 \u03a5\u03cc\u03c1\u03ba\u03b7",
#             "he": "\u05e0\u05d9\u05d5 \u05d9\u05d5\u05e8\u05e7",
#             "pt": "Nova Iorque",
#             "eo": "Novjorko",
#             "oc": "N\u00f2va York",
#             "zh": "\u7ebd\u7ea6/\u7d10\u7d04",
#             "fa": "\u0646\u06cc\u0648\u06cc\u0648\u0631\u06a9",
#             "fr": "New York",
#             "ja": "\u30cb\u30e5\u30fc\u30e8\u30fc\u30af",
#             "ru": "\u041d\u044c\u044e-\u0419\u043e\u0440\u043a",
#             "be": "\u041d\u044c\u044e-\u0401\u0440\u043a",
#             "gl": "Nova York",
#             "de": "New York",
#             "uk": "\u041d\u044c\u044e-\u0419\u043e\u0440\u043a",
#             "ca": "Nova York",
#             "ko": "\ub274\uc695",
#             "te": "\u0c28\u0c4d\u0c2f\u0c42\u0c2f\u0c4a\u0c30\u0c4d\u0c15\u0c4d",
#             "it": "New York",
#             "cy": "Efrog Newydd",
#             "cs": "New York",
#             "is": "N\u00fdja J\u00f3rv\u00edk",
#             "vi": "New York"
#         },
#         "lat": 40.7127281,
#         "lon": -74.0060152,
#         "country": "US",
#         "state": "New York"
#     },
#     {
#         "name": "New York",
#         "local_names": {
#             "ta": "\u0ba8\u0bbf\u0baf\u0bc2 \u0baf\u0bcb\u0bb0\u0bcd\u0b95\u0bcd",
#             "en": "New York"
#         },
#         "lat": 55.0252998,
#         "lon": -1.4869496,
#         "country": "GB",
#         "state": "England"
#     },
#     {
#         "name": "New York",
#         "local_names": {
#             "ta": "\u0ba8\u0bbf\u0baf\u0bc2 \u0baf\u0bcb\u0bb0\u0bcd\u0b95\u0bcd",
#             "en": "New York"
#         },
#         "lat": 39.6852874,
#         "lon": -93.9268836,
#         "country": "US",
#         "state": "Missouri"
#     },
#     {
#         "name": "New York",
#         "lat": 7.9631123,
#         "lon": -11.7636869,
#         "country": "SL",
#         "state": "Bo District"
#     },
#     {
#         "name": "Lake Oswego",
#         "local_names": {
#             "en": "Lake Oswego",
#             "ja": "\u30ec\u30a4\u30af\u30aa\u30b9\u30a6\u30a3\u30fc\u30b4"
#         },
#         "lat": 45.4206749,
#         "lon": -122.670649,
#         "country": "US",
#         "state": "Oregon"
#     }
# ]

# %%
def fetch_weather_data(api_key, lat, lon):
    url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={api_key}"
    response = requests.get(url)
    return response.json()

weather_data = fetch_weather_data(api_key, lat="40.7127281", lon="-74.0060152")
print(json.dumps(weather_data, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -74.0059,
#         "lat": 40.7128
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 295.81,
#         "feels_like": 295.67,
#         "temp_min": 289.8,
#         "temp_max": 301.25,
#         "pressure": 1018,
#         "humidity": 59
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 5.14,
#         "deg": 160
#     },
#     "clouds": {
#         "all": 0
#     },
#     "dt": 1714340097,
#     "sys": {
#         "type": 2,
#         "id": 2008101,
#         "country": "US",
#         "sunrise": 1714298267,
#         "sunset": 1714348130
#     },
#     "timezone": -14400,
#     "id": 5128581,
#     "name": "New York",
#     "cod": 200
# }
